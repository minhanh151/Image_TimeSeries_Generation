# %%
import pandas as pd
import matplotlib.pyplot as plt
max_rows = 365  # limit number of rows
exclude_columns = ['example_id', 'Volume', 'Adj_Close']

# Load CSV file
# csv_file = 'data/stock_data.csv'  # replace with your actual file name
csv_file = 'data/data.csv'  # replace with your actual file name
df = pd.read_csv(csv_file)

# Limit rows
# df = df.head(max_rows)
df = df[:365]

# Plot each column as a line
plt.figure(figsize=(12, 6))
for column in df.columns:
   if column not in exclude_columns:
       plt.plot(df.index, df[column], label=column)

# plt.yscale('log')  # Set Y-axis to logarithmic
plt.title('Line Plot per Column for synthetic data')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
max_rows = 365  # limit number of rows
exclude_columns = ['sample_id', 'Volume', 'Adj_Close']

# Load CSV file
csv_file = 'data/stock_data.csv'  # replace with your actual file name
# csv_file = 'data/data.csv'  # replace with your actual file name
df = pd.read_csv(csv_file)

# Limit rows
df = df.tail(max_rows)

# Plot each column as a line
plt.figure(figsize=(12, 6))
for column in df.columns:
   if column not in exclude_columns:
       plt.plot(df.index, df[column], label=column)

# plt.yscale('log')  # Set Y-axis to logarithmic
plt.title('Line Plot per Column for real data')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Load and preview dataset
import datetime
import pandas as pd
import numpy as np

pd.options.plotting.backend = "plotly"

day = 24 * 60 * 60
year = 365.2425 * day


def load_dataframe() -> pd.DataFrame:
    df = pd.DataFrame(columns=['date', 'sin'])
    df.date = pd.date_range(start='2018-01-01', end='2021-03-01', freq='D')
    df.sin = 1 + np.sin(df.date.astype('int64') // 1e9 * (2 * np.pi / year))
    df.sin = (df.sin * 100).round(2)
    df.date = df.date.apply(lambda d: d.strftime('%Y-%m-%d'))
    return df

trend_col = 'sin'
train_df = load_dataframe()
train_df.set_index('date').plot()

# %%
train_df.head()
# Out:
#          date     sin
# 0  2018-01-01  100.62
# 1  2018-01-02  102.34
# 2  2018-01-03  104.06
# 3  2018-01-04  105.78
# 4  2018-01-05  107.49
